# %%
import pandas as pd
import requests
import numpy as np
from config import settings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import requests
#       3 import numpy as np
# ----> 4 from config import settings
#
# File c:\Users\chake\OneDrive\Documents\GitHub\Working_with_APIs\config.py:11
#       8 import os
#      10 # pydantic used for data validation: https://pydantic-docs.helpmanual.io/
# ---> 11 from pydantic_settings  import BaseSettings
#      14 def return_full_path(filename: str = ".env") -> str:
#      15     """Uses os to return the correct path of the `.env` file."""
#
# ModuleNotFoundError: No module named 'pydantic_settings'

# %%
url = (
    "https://www.alphavantage.co/query?"
    "function=TIME_SERIES_DAILY&"
    "symbol=META&"
    f"apikey={settings.alpha_api_key}"
)
print("Type of url: ",type(url))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 url = (
#       2     "https://www.alphavantage.co/query?"
#       3     "function=TIME_SERIES_DAILY&"
#       4     "symbol=META&"
# ----> 5     f"apikey={settings.alpha_api_key}"
#       6 )
#       7 print("Type of url: ",type(url))
#
# NameError: name 'settings' is not defined

# %%
ticker = "META"
output_size = "compact"  # or "full"
data_type = "csv"  # or "json"

url = (
    "https://www.alphavantage.co/query?"
    "function=TIME_SERIES_DAILY&"
    f"symbol={ticker}&"
    f"outputsize={output_size}&"  # also note: no underscore here either
    f"datatype={data_type}&"
    f"apikey={settings.alpha_api_key}"
)

print("url type:", type(url))
print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       2 output_size = "compact"  # or "full"
#       3 data_type = "csv"  # or "json"
#       5 url = (
#       6     "https://www.alphavantage.co/query?"
#       7     "function=TIME_SERIES_DAILY&"
#       8     f"symbol={ticker}&"
#       9     f"outputsize={output_size}&"  # also note: no underscore here either
#      10     f"datatype={data_type}&"
# ---> 11     f"apikey={settings.alpha_api_key}"
#      12 )
#      14 print("url type:", type(url))
#      15 print(url)
#
# NameError: name 'settings' is not defined
