# %%
import pandas as pd
import requests
import numpy as np
from config import settings

# %%
url = (
    "https://www.alphavantage.co/query?"
    "function=TIME_SERIES_DAILY&"
    "symbol=META&"
    f"apikey={settings.alpha_api_key}"
)
print("Type of url: ",type(url))
# Out:
# Type of url:  <class 'str'>

# %%
ticker = "META"
output_size = "compact"  # or "full"
data_type = "csv"  # or "json"

url = (
    "https://www.alphavantage.co/query?"
    "function=TIME_SERIES_DAILY&"
    f"symbol={ticker}&"
    f"outputsize={output_size}&"  # also note: no underscore here either
    f"datatype={data_type}&"
    f"apikey={settings.alpha_api_key}"
)

print("url type:", type(url))
print(url)
# Out:
# url type: <class 'str'>
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=META&outputsize=compact&datatype=csv&apikey=VEW954O9LZK6FF9P
